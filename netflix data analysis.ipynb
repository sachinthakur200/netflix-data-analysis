# %%
import seaborn as sb
from matplotlib import pyplot as plt
import pandas as pd
df=pd.read_excel("c:/users/HP/documents/Netflix Dataset.xlsx")
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 07:19:00
# 2         s3    Movie                                 23:59:00
# 3         s4    Movie                                      9.0
# 4         s5    Movie                                     21.0
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   Show_Id Category     Title           Director  \
# 0      s1  TV Show      0.03                NaN
# 1      s2    Movie  07:19:00  Jorge Michel Grau
# 2      s3    Movie  23:59:00       Gilbert Chan
# 3      s4    Movie       9.0        Shane Acker
# 4      s5    Movie      21.0     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
# ...

# %%
df.shape    # it shows the totalo no of columns and rows in dataset
# Out:
# (7789, 11)

# %%
df.columns   # total no of columns in dataset
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.info()      # it shows info about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 669.5+ KB

# %% [markdown]
# # 1. is there any Duplicate Record in dataset ? if yes,then remove duplicate value

# %%
df[df.duplicated()] #it shows the duplicate values
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6300   2019-04-05  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622   2020-09-04  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)     # it drops the duplicate

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 07:19:00
# 2         s3    Movie                                 23:59:00
# 3         s4    Movie                                      9.0
# 4         s5    Movie                                     21.0
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # 2.is there any null value present in any column ?

# %%
df.isnull().sum()     #it show null values in each columns
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# df[df.title]

# %% [markdown]
# # 3. for 'House of Cards',what is the showid and who is director of the show ?

# %%
df[df.Title=='House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832   2018-11-02  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # 4. in which year highest number of Tv shows & movies are realesed? show with bar graph.

# %%
df.Release_Date.dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
df.Release_Date.dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4.how many Movies & Tv shows are in the dataset ? show with bar graph.

# %%
df.Category.value_counts()
# Out:
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
df.Category.value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# # 5. Show all the Movies that was realeased in 2014 ?

# %%
df['year']=df['Release_Date'].dt.year

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 1         s2    Movie                                 07:19:00
# 2         s3    Movie                                 23:59:00
# 3         s4    Movie                                      9.0
# 4         s5    Movie                                     21.0
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[(df.Category=='Movie') & (df.year==2014)]
# Out:
#      Show_Id Category                                              Title  \
# 914     s915    Movie             Bill Burr: I'm Sorry You Feel That Way
# 1026   s1027    Movie  BoJack Horseman Christmas Special: Sabrina's C...
# 1309   s1310    Movie         Chelsea Handler: Uganda Be Kidding Me Live
# 1310   s1311    Movie                 Chelsea Peretti: One of the Greats
# 1902   s1903    Movie                                             E-Team
# 2294   s2295    Movie                        From One Second to the Next
# 2386   s2387    Movie                                          Get Santa
# 3057   s3058    Movie          Iron Man & Captain America: Heroes United
# 3966   s3967    Movie            Marvel's Iron Man & Hulk: Heroes United
# 4147   s4148    Movie                                       Mission Blue
# 4153   s4154    Movie                                               Mitt
# 4333   s4334    Movie      My Little Pony Equestria Girls: Rainbow Rocks
# ...

# %% [markdown]
# # 6. show the titles of all the Tv shows that were released in india.

# %%
df[(df.Category=='TV Show') & (df.Country=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # 7. Show Top 10 Director,who gave the highest number of Tv shows & Movies to netflix ?

# %%
df.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# # 8.show all the records,where Category is Movie and type is comedies or country is united kingdom.

# %%
df[(df.Category=='Movie') & (df.Type=='Comedies') | (df.Country=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                      89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # 9. in how many movies\shows,Tom cruise was cast ?

# %%
df[df.Cast.str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_196/3369377395.py in <module>
# ----> 1 df[df.Cast.str.contains('Tom Cruise')]
#
# F:\anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# F:\anaconda\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
newdata=df.dropna() # it drops the null values 
                    #  drop null values here because str.contains cannot run with null values

# %%
newdata[newdata.Cast.str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description
# 3860  Through chance, human action, past history and...
# 5071  A fast-talking yuppie is forced to slow down w...

# %% [markdown]
# # 10.how many Movies got 'TV-14' rating,in canada ?

# %%
df[(df.Category=='Movie') & (df.Rating=='TV-14') & (df.Country=='Canada')].shape
# Out:
# (11, 11)

# %% [markdown]
# # 11.How many TV shows got 'R' rating after 2018 ?

# %%
df[(df.Category=='TV Show') & (df.Rating=='R') & (df.year>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %% [markdown]
# # 12.which country has highest no of TV shows ?

# %%
data_tvshow=df[df.Category=='TV Show']

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # 13. how can we sort dataset by year ?

# %%
df.sort_values(by='year',ascending=False)
# Out:
#      Show_Id Category                         Title  \
# 7353   s7352    Movie                       Unknown
# 2013   s2014    Movie              Enter the Dragon
# 2349   s2350    Movie                     Gangaajal
# 1497   s1498    Movie                Cool Hand Luke
# 1194   s1195    Movie             Can't Hardly Wait
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5138   s5138  TV Show                  Red vs. Blue
# 6066   s6066  TV Show  The Adventures of Figaro Pho
#
#                           Director  \
# 7353            Jaume Collet-Serra
# 2013                 Robert Clouse
# 2349                   Prakash Jha
# 1497              Stuart Rosenberg
# 1194  Harry Elfont, Deborah Kaplan
# ...                            ...
# 3374                           NaN
# 3492                           NaN
# ...

# %%
df[(df.Category=='Movie') & (df.Country=='India')].shape
# Out:
# (852, 12)

# %%
df.groupby('Country')['Category'].count().sort_values(ascending=False)
# Out:
# Country
# United States                        2556
# India                                 923
# United Kingdom                        397
# Japan                                 226
# South Korea                           183
#                                      ...
# Indonesia, South Korea, Singapore       1
# Indonesia, United Kingdom               1
# Indonesia, United States                1
# Iran, France                            1
# Zimbabwe                                1
# Name: Category, Length: 681, dtype: int64

# %% [markdown]
# # 14. show top 10 country with highest no. of Movie

# %%
datamovie=df[df.Category=='Movie']

# %%
datamovie.Country.value_counts().head(10)
# Out:
# United States     1851
# India              852
# United Kingdom     193
# Canada             118
# Spain               89
# Egypt               89
# Turkey              73
# Philippines         70
# France              69
# Japan               69
# Name: Country, dtype: int64

# %%
datamovie.Country.value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # 15.actor with most no. of movies

# %%
datamovie.Cast.value_counts().sort_values(ascending=False).head(1)
# Out:
# Samuel West    10
# Name: Cast, dtype: int64

# %% [markdown]
# # 16. how many Tv show with seasons ?

# %%
data_tvshow[data_tvshow.Duration.str.contains('Season')].shape
# Out:
# (2410, 11)

# %% [markdown]
# # 17. show yearwise realesed TV shows with bar graph ?

# %%
data_tvshow.Release_Date.dt.year.value_counts()
# Out:
# 2020.0    697
# 2019.0    656
# 2018.0    430
# 2017.0    361
# 2016.0    185
# 2015.0     30
# 2021.0     29
# 2014.0      6
# 2013.0      5
# 2008.0      1
# Name: Release_Date, dtype: int64

# %%
data_tvshow.Release_Date.dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 18. show year wise released movie ?

# %%
datamovie.Release_Date.dt.year.value_counts()
# Out:
# 2019    1498
# 2020    1313
# 2018    1255
# 2017     864
# 2016     258
# 2021      88
# 2015      58
# 2014      19
# 2011      13
# 2013       6
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: Release_Date, dtype: int64

# %%
datamovie.Release_Date.dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 19. how many Tv shows/movies were released in india per year ?

# %%
df[df['Country'].isin(['India'])].shape
# Out:
# (923, 11)

# %%
india=df[df['Country'].isin(['India'])]

# %%
india.Release_Date.dt.year.value_counts()
# Out:
# 2018    340
# 2019    225
# 2020    192
# 2017    143
# 2021     12
# 2016     11
# Name: Release_Date, dtype: int64

# %%
india.Release_Date.dt.year.value_counts().plot(kind='bar',color=['r','b','g'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 20. how many Tv show and Movies realesed in india ?

# %%
india.Category.value_counts()
# Out:
# Movie      852
# TV Show     71
# Name: Category, dtype: int64

# %%
india.Category.value_counts().plot(kind='pie',autopct='%.2f',explode=(.1,0))
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# #  21.which type of Tv shows/movies are realeased most ?

# %%
df.groupby('Type').Category.count().sort_values(ascending=False).head(1)
# Out:
# Type
# Documentaries    334
# Name: Category, dtype: int64

# %% [markdown]
# #  22.which type of Tv shows/movies are realeased most in india?

# %%
india.groupby('Type').Category.count().sort_values(ascending=False).head(1)
# Out:
# Type
# Dramas, International Movies    116
# Name: Category, dtype: int64

# %% [markdown]
# # 23.which director gave the maximum no. of movies in india ?

# %%
india_movie=india[india.Category=='Movie']

# %%
india_movie.Director.value_counts()
# Out:
# David Dhawan             9
# Ashutosh Gowariker       6
# Sooraj R. Barjatya       6
# Anees Bazmee             6
# Rajkumar Santoshi        6
#                         ..
# Rakshith Thirthahalli    1
# Vishnu Govindhan         1
# Sajid Khan               1
# Shawn Arranha            1
# Mozez Singh              1
# Name: Director, Length: 607, dtype: int64

# %%
df[df.year==2020]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                     0.03
# 4         s5    Movie                                     21.0
# 6         s7    Movie                                    122.0
# 14       s15    Movie                                   3022.0
# 24       s25  TV Show      ​SAINT SEIYA: Knights of the Zodiac
# ...      ...      ...                                      ...
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 0                 NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # 24. show year-wise realeased Tv shows & movies with bar graph

# %%
plt.figure(figsize=(10,10))
sb.countplot(x=df.year,hue=df.Category)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   datetime64[ns]
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 669.5+ KB

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')
